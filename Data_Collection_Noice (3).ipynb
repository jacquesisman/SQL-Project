# %%
from apiclient.discovery import build

# Import package to make HTPP requests, fetch URL similar to browser request
import requests

# Import json library to decode json 
import json 
# import for data manipulation and analysis 
import pandas as pd

# %%
API_KEY = '***********'

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
snippets = youtube.search().list(part='snippet',q='NOICE', type='channel').execute()

# %%
channelId = snippets['items'][0]['snippet']['channelId']

# %%
content = youtube.channels().list(id = channelId, part = 'contentDetails').execute()
print(content)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'Ip6RtPBomtazVlVj91iOFxWlejQ', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'b-9E6DT-XhVPuOBvWt0FlVOrflk', 'id': 'UCU7U3fcM-PQs39jFSj5pVMg', 'contentDetails': {'relatedPlaylists': {'likes': '', 'favorites': '', 'uploads': 'UUU7U3fcM-PQs39jFSj5pVMg'}}}]}

# %%
uploadId = content['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# %%
stats = youtube.channels().list(part="statistics", id = channelId).execute()

# %%
stats
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '5sQUGtibsF7GvHBCXqQzNA2Etto',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'U4GxZYpg080m40jIa405VXGOCYc',
#    'id': 'UCU7U3fcM-PQs39jFSj5pVMg',
#    'statistics': {'viewCount': '975433',
#     'subscriberCount': '14400',
#     'hiddenSubscriberCount': False,
#     'videoCount': '88'}}]}

# %%
allVideos = []

# %%
nextPage_token = None

# %%
res = youtube.playlistItems().list(playlistId = uploadId,maxResults = 50, part = 'snippet', pageToken = nextPage_token).execute()

# %%
while 1: 
    res = youtube.playlistItems().list(playlistId = uploadId,maxResults = 50, part = 'snippet', pageToken = nextPage_token).execute()
    
    allVideos += res['items']
    
    nextPage_token = res.get('nextPageToken')
    
    if nextPage_token is None: 
        break
        
    print(allVideos)
# Out:
# [{'kind': 'youtube#playlistItem', 'etag': 'gc-MvcIoWvyPbnQfClo0znK7HeU', 'id': 'VVVVN1UzZmNNLVBRczM5akZTajVwVk1nLjZqTmlkLUp2TUpj', 'snippet': {'publishedAt': '2021-04-06T06:17:26Z', 'channelId': 'UCU7U3fcM-PQs39jFSj5pVMg', 'title': '[Noice Collab Week] Jadi Maling di Rumah Sendiri | Happy Broken Family ft Arya Novrianus', 'description': 'Dengerin obrolan lengkap Happy Broken Family ft Podcast Romance Dawn cuma di aplikasi Noice - https://open.noice.id/content/b069eac8-c0aa-4966-88ff-8e0ef8bbc8df\n#HappyBrokenFamily #BrokenHome #Noice\n--------------------------------------------------------------------------------------------------------------------------------------------------------------\nDownload Noice sekarang, Gratis! \nApp Store: https://apps.apple.com/id/app/noice-radio-music-podcast/id1484372791\nPlaystore: https://play.google.com/store/apps/details?id=noice.app\n\nDengerin beragam konten audio seru, mulai dari podcast, musik, dan radio. Temuin juga konten audio eksklusif yang cuma bisa kamu dengerin di Noice. Ngobrol seru-seruan bareng Paranoice & podcaster-nya langsung di aplikasi. Jadi kamu nggak perlu takut sepi sendiri karena Noice bakal jadi teman yang siap sedia dalam genggamanmu kapan pun, di mana pun! \n\nNoice. Teman dalam Genggaman!\n\nKeep in touch, yuk! Follow media sosial Noice yang lain juga \nInstagram: https://www.instagram.com/noice.id/\nTwitter: https://twitter.com/noice_id\nTiktok: https://vt.tiktok.com/ZSGo5ge5/', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'NOICE', 'playlistId': 'UUU7U3fcM-PQs39jFSj5pVMg', 'position': 0, 'resourceId': {'kind': 'youtube#video', 'videoId': '6jNid-JvMJc'}, 'videoOwnerChannelTitle': 'NOICE', 'videoOwnerChannelId': 'UCU7U3fcM-PQs39jFSj5pVMg'}}, {'kind': 'youtube#playlistItem', 'etag': 'nszIFbDEbFmYJnvthcARGqaBiSY', 'id': 'VVVVN1UzZmNNLVBRczM5akZTajVwVk1nLmpNTnh3YmdaLW5F', 'snippet': {'publishedAt': '2021-04-05T06:19:22Z', 'channelId': 'UCU7U3fcM-PQs39jFSj5pVMg', 'title': 'Coki Pardede VS NETIZEN with Hesti Purwadinata', 'description': 'Dengerin obrolan lengkapnya cuma di aplikasi Noice - https://open.noice.id/content/328df502-d208-44da-954c-3692f87b7772\n#HestiPurwadinata #CokiPardede #Noice\n--------------------------------------------------------------------------------------------------------------------------------------------------------------\nDownload Noice sekarang, Gratis! \nApp Store: https://apps.apple.com/id/app/noice-radio-music-podcast/id1484372791\nPlaystore: https://play.google.com/store/apps/details?id=noice.app\n\nDengerin beragam konten audio seru, mulai dari podcast, musik, dan radio. Temuin juga konten audio eksklusif yang cuma bisa kamu dengerin di Noice. Ngobrol seru-seruan bareng Paranoice & podcaster-nya langsung di aplikasi. Jadi kamu nggak perlu takut sepi sendiri karena Noice bakal jadi teman yang siap sedia dalam genggamanmu kapan pun, di mana pun! \n\nNoice. Teman dalam Genggaman!\n\nKeep in touch, yuk! Follow media sosial Noice yang lain juga \nInstagram: https://www.instagram.com/noice.id/\nTwitter: https://twitter.com/noice_id\nTiktok: https://vt.tiktok.com/ZSGo5ge5/', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jMNxwbgZ-nE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/jMNxwbgZ-nE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/jMNxwbgZ-nE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/jMNxwbgZ-nE/sddefault.jpg', 'width':  ...

# %%
allVideos[0]['snippet']
# Out:
# {'publishedAt': '2021-04-06T06:17:26Z',
#  'channelId': 'UCU7U3fcM-PQs39jFSj5pVMg',
#  'title': '[Noice Collab Week] Jadi Maling di Rumah Sendiri | Happy Broken Family ft Arya Novrianus',
#  'description': 'Dengerin obrolan lengkap Happy Broken Family ft Podcast Romance Dawn cuma di aplikasi Noice - https://open.noice.id/content/b069eac8-c0aa-4966-88ff-8e0ef8bbc8df\n#HappyBrokenFamily #BrokenHome #Noice\n--------------------------------------------------------------------------------------------------------------------------------------------------------------\nDownload Noice sekarang, Gratis! \nApp Store: https://apps.apple.com/id/app/noice-radio-music-podcast/id1484372791\nPlaystore: https://play.google.com/store/apps/details?id=noice.app\n\nDengerin beragam konten audio seru, mulai dari podcast, musik, dan radio. Temuin juga konten audio eksklusif yang cuma bisa kamu dengerin di Noice. Ngobrol seru-seruan bareng Paranoice & podcaster-nya langsung di aplikasi. Jadi kamu nggak perlu takut sepi sendiri karena Noice bakal jadi teman yang siap sedia dalam genggamanmu kapan pun, di mana pun! \n\nNoice. Teman dalam Genggaman!\n\nKeep in touch, yuk! Follow media sosial Noice yang lain juga \nInstagram: https://www.instagram.com/noice.id/\nTwitter: https://twitter.com/noice_id\nTiktok: https://vt.tiktok.com/ZSGo5ge5/',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/6jNid-JvMJc/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'channelTitle': 'NOICE',
#  'playlistId': 'UUU7U3fcM-PQs39jFSj5pVMg',
#  'position': 0,
#  'resourceId': {'kind': 'youtube#video', 'videoId': '6jNid-JvMJc'},
#  'videoOwnerChannelTitle': 'NOICE',
#  'videoOwnerChannelId': 'UCU7U3fcM-PQs39jFSj5pVMg'}

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], allVideos))
print(len(video_ids))
# Out:
# 88

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats += res['items']
print(stats)
# Out:
# [{'kind': 'youtube#video', 'etag': 'YtXsFpJAnaKDo7lbbYbhg5zbs2A', 'id': '6jNid-JvMJc', 'statistics': {'viewCount': '766', 'likeCount': '27', 'dislikeCount': '2', 'favoriteCount': '0', 'commentCount': '3'}}, {'kind': 'youtube#video', 'etag': 'K89Ns0mZXthEGOhxJaeMBSwU6xk', 'id': 'jMNxwbgZ-nE', 'statistics': {'viewCount': '76370', 'likeCount': '2415', 'dislikeCount': '26', 'favoriteCount': '0', 'commentCount': '234'}}, {'kind': 'youtube#video', 'etag': 'L9OxL3rPO3MX0zDW5QhnyM8eYJg', 'id': 'D9D6ulKFB8o', 'statistics': {'viewCount': '3835', 'likeCount': '116', 'dislikeCount': '5', 'favoriteCount': '0', 'commentCount': '19'}}, {'kind': 'youtube#video', 'etag': 'OHxVMlKF5HEaiDvq4alx9FBVNHk', 'id': 'nSlUPlSnu8Q', 'statistics': {'viewCount': '8364', 'likeCount': '253', 'dislikeCount': '2', 'favoriteCount': '0', 'commentCount': '22'}}, {'kind': 'youtube#video', 'etag': 'c-HXvb9R6gk5_UIgSuBhsbj8YSI', 'id': 'LhUXpvMg9DQ', 'statistics': {'viewCount': '2638', 'likeCount': '68', 'dislikeCount': '2', 'favoriteCount': '0', 'commentCount': '8'}}, {'kind': 'youtube#video', 'etag': 'IM_7dQNu48cEJvP60NB2UuPLlHo', 'id': 'jGI5VwgXTEw', 'statistics': {'viewCount': '1671', 'likeCount': '52', 'dislikeCount': '3', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': 'Vql_LUQhIyUARvwUaJzhIP2I2xc', 'id': 'zL8Kuqt7eZA', 'statistics': {'viewCount': '548', 'likeCount': '15', 'dislikeCount': '2', 'favoriteCount': '0', 'commentCount': '1'}}, {'kind': 'youtube#video', 'etag': 'dui7aDxJ9mjkUsTUMbv75EHQJEw', 'id': 'IAN2-T3bm50', 'statistics': {'viewCount': '481', 'likeCount': '8', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '2'}}, {'kind': 'youtube#video', 'etag': 's_gBVhuma2EwB-fZ7I-Kn3YOS4U', 'id': 'EOM1V4slROE', 'statistics': {'viewCount': '4008', 'likeCount': '107', 'dislikeCount': '1', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': 'N2lzgzP8_95d5yjCEN8YSkZ3tAI', 'id': 'Kv6cuU8__C4', 'statistics': {'viewCount': '3134', 'likeCount': '33', 'dislikeCount': '1', 'favoriteCount': '0', 'commentCount': '2'}}, {'kind': 'youtube#video', 'etag': '8EgJk3p5zq84TFBMM-MVOq4bfLQ', 'id': '0vGLBJFqffE', 'statistics': {'viewCount': '772', 'likeCount': '32', 'dislikeCount': '3', 'favoriteCount': '0', 'commentCount': '8'}}, {'kind': 'youtube#video', 'etag': 'FaPSbit1V-yLUM_q1nVLQ-OQ4fM', 'id': 'I15g_8OTY7Q', 'statistics': {'viewCount': '4603', 'likeCount': '159', 'dislikeCount': '5', 'favoriteCount': '0', 'commentCount': '34'}}, {'kind': 'youtube#video', 'etag': '4L6uiCDlyty158qFZsW5TO4aJCA', 'id': 'YQK0Ht1Txl4', 'statistics': {'viewCount': '24263', 'likeCount': '661', 'dislikeCount': '13', 'favoriteCount': '0', 'commentCount': '65'}}, {'kind': 'youtube#video', 'etag': '2Xu9Dk4FK3DsZz8ANmSjWNoAYSM', 'id': 'Yc6qR026oTg', 'statistics': {'viewCount': '11690', 'likeCount': '419', 'dislikeCount': '22', 'favoriteCount': '0', 'commentCount': '121'}}, {'kind': 'youtube#video', 'etag': 'O03d1bwwMHM0IvfobRoaspvtork', 'id': 'IWFbzVR6sbo', 'statistics': {'viewCount': '3609', 'likeCount': '140', 'dislikeCount': '1', 'favoriteCount': '0', 'commentCount': '22'}}, {'kind': 'youtube#video', 'etag': 'vtIrL35kJzbxo5y-SFk4OBtEih0', 'id': 'u0-AKmXY3XM', 'statistics': {'viewCount': '1167', 'likeCount': '63', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '12'}}, {'kind': 'youtube#video', 'etag': '4hWUTwzAQ4rGj7qiV2ajmbWlzlA', 'id': 'Mgk8kqikc7U', 'statistics': {'viewCount': '775', 'likeCount': '28', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': '-Vrs5N9rgY8UXSiQ-la-eqnq96o', 'id': 'bgFWf5Bj9-s', 'statistics': {'viewCount': '5131', 'likeCount': '147', 'dislikeCount': '1', 'favoriteCount': '0', 'commentCount': '14'}}, {'kind': 'youtube#video', 'etag': 'BA6ZLYVw6FkBG5T9UapPUdKxFBs', 'id': 'wNdI152h3nI', 'statistics': {'viewCount': '680', 'likeCount': '26', 'dislikeCount': '0', 'favoriteCount': '0', 'commentCount': '4'}}, {'kind': 'youtube#video', 'etag': 'H4tnTn0mJ7j ...

# %%
title=[]
liked=[]
disliked=[]
views=[]
url=[]
comment=[]
videoid=[]
publishedDate=[]
video_description=[]

# %%
for i in range(0, 200):
    i += 1
    title.append((allVideos[i])['snippet']['title'])
    publishedDate.append((allVideos[i])['snippet']['publishedAt'])
    video_description.append((allVideos[i])['snippet']['description'])
    liked.append(int((stats[i])['statistics']['likeCount']))
    disliked.append(int((stats[i])['statistics']['dislikeCount']))
    views.append(int((stats[i])['statistics']['viewCount']))
    comment.append(int((stats[i])['statistics']['commentCount']))
    videoid.append((allVideos[i])['snippet']['resourceId']['videoId'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-bffb6da6c592> in <module>
#       1 for i in range(0, 200):
#       2     i += 1
# ----> 3     title.append((allVideos[i])['snippet']['title'])
#       4     publishedDate.append((allVideos[i])['snippet']['publishedAt'])
#       5     video_description.append((allVideos[i])['snippet']['description'])
#
# IndexError: list index out of range

# %%
data={'title':title,'videosIDS':videoid,'video_description':video_description,'publishedDate':publishedDate,'likes':liked,'dislikes':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df.head(300)
# Out:
#                                                 title    videosIDS  \
# 0      Coki Pardede VS NETIZEN with Hesti Purwadinata  jMNxwbgZ-nE
# 1   [NOICE Collab Week] Interlude x Berizik | Musi...  D9D6ulKFB8o
# 2   [NOICE Collab Week] Musuh Masyarakat x Happy B...  nSlUPlSnu8Q
# 3      Kemal Palevi VS Netizen with Hesti Purwadinata  LhUXpvMg9DQ
# 4   PEMALU (Pemuda Masa Lalu) | Soleh Solihun Anak...  jGI5VwgXTEw
# ..                                                ...          ...
# 82  BoBa | Eps. 1: Piala Dunia Antar Klub Gak Penting  QSwsmVE9QwE
# 83                   Teman Tidur | Eps. Cinta Pertama  chpaA4IkQoU
# 84       Obrolan Lelaki | Eps. 6: Koleksi Film Dewasa  mtkKeAeuGC8
# 85  Musuh Masyarakat | Eps 8: Sinetron Tidak Mendi...  jbY9eOmj1Pw
# 86                       NOICE: Radio, Music, Podcast  PFFsL16jjmM
#
#                                     video_description         publishedDate  \
# 0   Dengerin obrolan lengkapnya cuma di aplikasi N...  2021-04-05T06:19:22Z
# 1   Dengerin obrolan lengkapnya cuma di NOICE - ht...  2021-03-30T06:24:20Z
# 2   Dengerin obrolan selengkapnya cuma di NOICE - ...  2021-03-27T20:40:25Z
# 3   Dengerin podcast lengkapnya di aplikasi Noice!...  2021-03-26T22:23:41Z
# 4   Dengerin obrolan lengkapnya cuma di aplikasi N...  2021-03-24T03:20:50Z
# ..                                                ...                   ...
# 82  Dengerin lengkapnya di aplikasi NOICE!\n\nApp ...  2019-12-23T09:33:14Z
# 83  Dengerin lengkapnya di aplikasi NOICE!\n\nApp ...  2019-12-23T09:25:04Z
# 84  Dengerin lengkapnya di aplikasi NOICE!\n\nApp ...  2019-12-23T08:24:04Z
# 85  Dengerin lengkapnya di aplikasi NOICE!\nEps 8:...  2019-12-23T08:17:33Z
# 86  NOICE: Rumah Konten Audio Indoensia.\nRadio, M...  2019-12-23T07:32:19Z
#
#     likes  dislikes   views  comment
# 0    2415        26   76370      234
# 1     116         5    3835       19
# 2     253         2    8364       22
# 3      68         2    2638        8
# 4      52         3    1671        4
# ..    ...       ...     ...      ...
# 82      7         0     625        0
# 83      5         0     617        0
# 84      5         0    1178        0
# 85   2276        74  202496       53
# 86     16         1    3067        2
#
# [87 rows x 8 columns]

# %%
df.to_csv('ExtractedYoutubeDataNOICE.csv',index=False)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://********:*******@********.us-east-2.rds.amazonaws.com/*****?charset=utf8')

# %%
df.to_sql('Noice', engine, if_exists='replace', index=False)
